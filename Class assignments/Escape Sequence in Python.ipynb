# %% [markdown]
# # Escape Sequence in Python

# %% [markdown]
# ![table6-1-2.JPG](attachment:table6-1-2.JPG)

# %%
print("He said,"Yesterday, it rained heavily."")
# Out:
#   Cell In[4], line 1
#     print("He said,"Yesterday, it rained heavily."()")
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print('He said,'Yesterday, it rained heavily.'')
# Out:
#   Cell In[5], line 1
#     print('He said,'Yesterday, it rained heavily.'')
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
#Example: " '  '  "
print("He said, 'Yesterday, it rained heavily.'")
# Out:
# He said, 'Yesterday, it rained heavily.'

# %%
#Example: '  "  "  '
print('He said, "Yesterday, it rained heavily."')
# Out:
# He said, "Yesterday, it rained heavily."

# %%
#Example: \'
print('He said, \'Yesterday, it rained heavily.\'')
# Out:
# He said, 'Yesterday, it rained heavily.'

# %%
#Example: \"
print("He said, \"Yesterday, it rained heavily.\"")
# Out:
# He said,
# "Yesterday, it rained heavily."

# %%
print("E:\NextStepInfoTechCourses\Python Batch 12\02 Getting Started")
# Out:
#   Cell In[12], line 1
#     print("E:\NextStepInfoTechCourses\Python Batch 12\02 Getting Started")
#                                                                          ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: malformed \N character escape

# %%
#Example: \\
print("C:\\Users\\Desktop\\NextStepInfoTechPythonFoundation\\02 Getting Started")
# Out:
# C:\Users\Desktop\NextStepInfoTechPythonFoundation\02 Getting Started

# %%
path = r"E:\NextStepInfoTechCourses\Python Batch 12\02 Getting Started"
print(path)
# Out:
# E:\NextStepInfoTechCourses\Python Batch 12\02 Getting Started

# %%
#Example: \a
print("Hello \a World")
# Out:
# Hello  World

# %%
#Example: \b
print("Hello \bWorld")
# Out:
# World

# %%
#Example: \f
print("Hello \f World")
# Out:
# Hello  World

# %%
#Example: \n
print("Hello \n World")
# Out:
# Hello
#  World

# %%
#Example: \r
print("Hello \rWorld")
# Out:
# World

# %%
#Example: \t
print("Hello \t World")
# Out:
# Hello 	 World

# %%
#Example: \v
print("Hello \v World")
# Out:
# Hello  World

# %% [markdown]
# ## Write a Python program to print the following string in a specific format (see the output).

# %% [markdown]
# "Everybody in this country should learn to program a computer,<br>
#  because it teaches you how to think."<br>
#  &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;- STEVE JOBS

# %%
print("Everybody in this country should learn to program a computer,\nbecause it teaches you how to think.\n\t\t\t -STEVE JOBS")
# Out:
# Everybody in this country should learn to program a computer,
# because it teaches you how to think.
# 			 -STEVE JOBS
