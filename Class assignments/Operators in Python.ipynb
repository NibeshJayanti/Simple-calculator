# %% [markdown]
# # Arithmetic Operators in Python

# %% [markdown]
# Arithmetic Operators are used to perform basic arithmetic operations like addition, subtraction, division etc.

# %% [markdown]
# ![arithmetic-operation-in-python.png](attachment:arithmetic-operation-in-python.png)

# %%
#Examples

# %%
5+2
# Out:
# 7

# %%
4-3
# Out:
# 1

# %%
7*2
# Out:
# 14

# %%
4/2
# Out:
# 2.0

# %%
10%3
# Out:
# 1

# %%
2**5
# Out:
# 32

# %%
10//3
# Out:
# 3

# %%
-5//2
# Out:
# -3

# %% [markdown]
# # Relational or Comparison Operator in Python

# %% [markdown]
# Relational operators are used to compare the value of operands (expressions) to produce a logical value. A logical value is either True or False.

# %% [markdown]
# ![relational-operator-in-python.png](attachment:relational-operator-in-python.png)

# %%
#Example

# %%
5<2
# Out:
# False

# %%
5>2
# Out:
# True

# %%
10<=10
# Out:
# True

# %%
10>=12
# Out:
# False

# %%
10==10
# Out:
# True

# %%
5!=2
# Out:
# True

# %% [markdown]
# # Logical Operators in Python

# %% [markdown]
# Logical operators are used to connect more relational operations to form a complex expression called logical expression. A value obtained by evaluating a logical expression is always logical, i.e. either True or False.

# %% [markdown]
# ![logical-operator-in-python-1.png](attachment:logical-operator-in-python-1.png)

# %% [markdown]
# ## Logical And

# %% [markdown]
# ![and-in-python.png](attachment:and-in-python.png)

# %% [markdown]
# True and Expression1 and Expression2 = Expression2

# %% [markdown]
# False and Expression1 and Expression2 = False

# %%
#Example:
a = 5
b = 10
c = 15
a<b
# Out:
# True

# %%
b<c
# Out:
# True

# %%
a<b and b<c
# Out:
# True

# %%
a>b and b<c
# Out:
# False

# %%
a<b and b>c
# Out:
# False

# %%
a>b and b>c
# Out:
# False

# %%
d = 20
a<b and b<c and d
# Out:
# 20

# %%
bool(20)
# Out:
# True

# %%
a>b and b<c and d
# Out:
# False

# %%
d and a<b  and b<c
# Out:
# True

# %% [markdown]
# ## Logical Or

# %% [markdown]
# ![or-in-python.png](attachment:or-in-python.png)

# %% [markdown]
# True or Expression1 or Expression2 = True

# %% [markdown]
# False or Expression1 or Expression2 = Expression1

# %%
#Example:

# %%
#Example:
a = 5
b = 10
c = 15
a<b
# Out:
# True

# %%
b<c
# Out:
# True

# %%
a<b or b<c
# Out:
# True

# %%
a>b or b<c
# Out:
# True

# %%
a<b or b>c
# Out:
# True

# %%
a>b or b>c
# Out:
# False

# %%
d = 20
a<b or b<c or d
# Out:
# True

# %%
bool(20)
# Out:
# True

# %%
a>b or b>c or d
# Out:
# 20

# %%
d or a<b  or b<c
# Out:
# 20

# %% [markdown]
# ## Logical Not

# %% [markdown]
# ![not-in-python.png](attachment:not-in-python.png)

# %%
#Example:

# %%
not(a<b)
# Out:
# False

# %%
not(b>c)
# Out:
# True

# %% [markdown]
# # Assignment Operators in Python

# %% [markdown]
# Assignment operators are used to perform arithmetic operations while assigning value to a variable.

# %% [markdown]
# ![assignment-operator-in-python.png](attachment:assignment-operator-in-python.png)

# %%
#Example:

# %%
x = 10
print(x)
x = x+5
print(x)
# Out:
# 10
# 15

# %%
x = 10
print(x)
x += 5
print(x)
# Out:
# 10
# 15

# %%
x = 10
print(x)
x -= 5
print(x)
# Out:
# 10
# 5

# %%
x = 10
print(x)
x *= 5
print(x)
# Out:
# 10
# 50

# %%
x = 10
print(x)
x /= 5
print(x)
# Out:
# 10
# 2.0

# %%
x = 10
print(x)
x **= 5
print(x)
# Out:
# 10
# 100000

# %%
x = 10
print(x)
x %= 3
print(x)
# Out:
# 10
# 1

# %%
x = 10
print(x)
x //= 3
print(x)
# Out:
# 10
# 3

# %% [markdown]
# # Bitwise Operators in Python

# %% [markdown]
# Bitwise operators are used to perform operations at binary digit level. These operators are not commonly used and are used only in special applications where optimized use of storage is required.

# %% [markdown]
# ![bitwise-opeartor-in-python.png](attachment:bitwise-opeartor-in-python.png)

# %% [markdown]
# ## Bitwise AND

# %% [markdown]
# ![bitwise-and-operator-in-python.png](attachment:bitwise-and-operator-in-python.png)

# %% [markdown]
# ## Bitwise OR

# %% [markdown]
# ![bitwise-or-operator-in-python.png](attachment:bitwise-or-operator-in-python.png)

# %% [markdown]
# ## Bitwise XOR

# %% [markdown]
# ![bitwise-xor-operator-in-pyton.png](attachment:bitwise-xor-operator-in-pyton.png)

# %% [markdown]
# ## Bitwise NOT

# %% [markdown]
# ![bitwise-not-in-python.png](attachment:bitwise-not-in-python.png)

# %%
a = 10
b = 8
print(bin(a))
print(bin(b))
 
# Print bitwise AND operation
print("bitwise AND operation")
print("a & b =", a & b)
print("a & b in binary =", bin(a & b))
print()
 
# Print bitwise OR operation
print("bitwise OR operation")
print("a | b =", a | b)
print("a | b in binary =", bin(a | b))
print()
 
# Print bitwise NOT operation
print("bitwise NOT operation")
print("~a =", ~a)
print("~a in binary =", bin(~a))
print()
 
# print bitwise XOR operation
print("bitwise XOR operation")
print("a ^ b =", a ^ b)
print("a ^ b in binary =", bin(a ^ b))
# Out:
# 0b1010
# 0b1000
# bitwise AND operation
# a & b = 8
# a & b in binary = 0b1000
#
# bitwise OR operation
# a | b = 10
# a | b in binary = 0b1010
#
# bitwise NOT operation
# ~a = -11
# ~a in binary = -0b1011
#
# bitwise XOR operation
# a ^ b = 2
# a ^ b in binary = 0b10

# %% [markdown]
# ## Bitwise Left Swift

# %% [markdown]
# ![bitwise-left-shift-in-python.png](attachment:bitwise-left-shift-in-python.png)

# %% [markdown]
# ## Bitwise Right Swift

# %% [markdown]
# ![bitwise-right-sift.png](attachment:bitwise-right-sift.png)

# %%
# Python program to show
# shift operators
 
a = 10
b = -10
print(bin(a))
print(bin(b))
 
# print bitwise right shift operator
print("a >> 1 =", a >> 1)
print("b >> 1 =", b >> 1)
 
a = 5
b = -10
 
# print bitwise left shift operator
print("a << 1 =", a << 1)
print("b << 1 =", b << 1)
# Out:
# 0b1010
# -0b1010
# a >> 1 = 5
# b >> 1 = -5
# a << 1 = 10
# b << 1 = -20

# %% [markdown]
# # Membership Operators in Python

# %% [markdown]
# The membership operators are useful to test for membership in a sequence such as string, lists, tuples and dictionaries.
# There are two type of Membership operator:

# %% [markdown]
# 1. in
# 2. not in

# %% [markdown]
# ## in

# %% [markdown]
# This operators is used to find an element in the specified sequence.
#
# It returns True if element is found in the specified sequence else it returns False.

# %%
#Examples:
lst = [12,45,85,885,74]
85 in lst
# Out:
# True

# %%
75 in lst
# Out:
# False

# %% [markdown]
# ## not in

# %% [markdown]
# This operators works in reverse manner for in operator.
#
# It returns True if element is not found in the specified sequence and if element is found, then it returns False.

# %%
#Examples:

# %%
85 not in lst
# Out:
# False

# %%
75 not in lst
# Out:
# True

# %% [markdown]
# # Identity Operators in Python

# %% [markdown]
# The identity operators compare the memory locations of two objects. Hence, it is possible to know whether two objects are same or not.

# %% [markdown]
# There are two types of identity operators:

# %% [markdown]
# 1. is
# 2. is not

# %% [markdown]
# ## is

# %% [markdown]
# This operator is used to compare whether two objects are same or not.

# %% [markdown]
# It returns True if memory location of two objects are same else it returns False.

# %%
#Example:

# %%
lst1 = [132,456,789]
lst2 = lst1.copy()
print(lst1, lst2)
# Out:
# [132, 456, 789] [132, 456, 789]

# %%
lst1 == lst2
# Out:
# True

# %%
lst1 is lst2
# Out:
# False

# %% [markdown]
# ## is not

# %% [markdown]
# This operator works in reverse manner for **is** operator.

# %% [markdown]
# It returns True if memory location of two objects are not same and if they are same it returns False.

# %%
#Example:
lst1 is not lst2
# Out:
# True

# %% [markdown]
# # Operator Precedence and Associativity in Python

# %% [markdown]
# The computer scans an expression which contains the operators from left to right and performs only one operation at a time.

# %% [markdown]
# The expression will be scanned many times to produce to result.

# %% [markdown]
# The order in which various operations are performed is known as hierarchy of operations or operator precedence.

# %% [markdown]
# Some of the operators of the same level of precedence are evaluated from left to right or right to left. This is referred to associativity.

# %% [markdown]
# ![1_XCOKzXaTZVWkU-g7ZGdqKQ.png](attachment:1_XCOKzXaTZVWkU-g7ZGdqKQ.png)

# %%
#Example: Simple Math
(1+1)*2**4//3+4-1
# Out:
# 13

# %%
#(1+1)*2**4//3+4-1
# 2 * 2**4 //3+4-1
# 2*16//3+4-1
# 32//3+4-1
# 10+4-1
# 14-1
# 13

# %%
#Example: Exponential precedence
2**3**2
# Out:
# 512

# %% [markdown]
# 2**9
#
# 512

# %%
#Example: With logical operators
5>2 and (10>7 or 7<10) and not 5==5
# Out:
# False

# %%
# 5>2 and (10>7 or 7<10) and not 5==5
# 5>2 and (True or 7<10) and not 5=5
# 5>2 and (True or True) and not 5=5
# 5>2 and True and not 5==5
# True and True and not 5 == 5
# True and True and not True
# True and True and False
# True and False
# False

# %%
#Example: With logical operators
5>2 and 10>7 or 7<10 and not 5==5
# Out:
# True
